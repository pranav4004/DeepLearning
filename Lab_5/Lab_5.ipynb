# %% [markdown]
# # Handwritten Digit recognition using CNN

# %% [markdown]
# # import the libararies

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# # Preprocessing data

# %%
num_classes=10
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train/255
x_test = x_test/255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # Create the model

# %%
batch_size = 128
num_classes = 10
epochs = 10
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])
# Out:
# c:\Users\Subbu\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Train the model

# %%
hist=model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")
model.save('mnist.h5')
print("Saving the model as mnist.h5")
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 117s 246ms/step - accuracy: 0.1119 - loss: 2.3000 - val_accuracy: 0.3149 - val_loss: 2.2401
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 209s 446ms/step - accuracy: 0.2430 - loss: 2.2311 - val_accuracy: 0.5265 - val_loss: 2.1531
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 111ms/step - accuracy: 0.3915 - loss: 2.1453 - val_accuracy: 0.6215 - val_loss: 2.0332
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 124s 265ms/step - accuracy: 0.4953 - loss: 2.0270 - val_accuracy: 0.6795 - val_loss: 1.8674
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 227ms/step - accuracy: 0.5706 - loss: 1.8657 - val_accuracy: 0.7277 - val_loss: 1.6529
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 66s 64ms/step - accuracy: 0.6202 - loss: 1.6629 - val_accuracy: 0.7717 - val_loss: 1.4086
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.6550 - loss: 1.4528 - val_accuracy: 0.8024 - val_loss: 1.1734
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 69ms/step - accuracy: 0.6851 - loss: 1.2569 - val_accuracy: 0.8204 - val_loss: 0.9805
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.7122 - loss: 1.0914 - val_accuracy: 0.8329 - val_loss: 0.8363
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 36s 76ms/step - accuracy: 0.7244 - loss: 0.9834 - val_accuracy: 0.8420 - val_loss: 0.7327
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# The model has successfully trained
# Saving the model as mnist.h5

# %% [markdown]
# # Evaluate the model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.7326789498329163
# Test accuracy: 0.8420000076293945

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,359,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,142,816 (27.25 MB)
#  Trainable params: 2,380,938 (9.08 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 4,761,878 (18.17 MB)

# %% [markdown]
# #  Predict digits

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load the model
model = tf.keras.models.load_model('mnist.h5')

# Load MNIST data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_test = np.expand_dims(x_test, -1) / 255.0  # Normalize and add channel dimension

# Test the model with some test images
for i in range(10):
    img = x_test[i]
    label = y_test[i]
    img = np.expand_dims(img, 0)  # Add batch dimension
    prediction = model.predict(img)[0]
    predicted_class = np.argmax(prediction)
    probability = np.max(prediction)
    
    # Plot the image and prediction
    plt.imshow(img[0, :, :, 0], cmap='gray')
    plt.title(f'Label: {label}, Prediction: {predicted_class}, Probability: {probability:.2f}')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Plot both validation loss and training loss
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Improve the model accuracy version 1 with 20 epochs

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
num_classes=10
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train/255
x_test = x_test/255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
batch_size = 128
num_classes = 10
epochs = 20
model_2 = Sequential()
model_2.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model_2.add(Conv2D(64, (3, 3), activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2, 2)))
model_2.add(Dropout(0.25))
model_2.add(Flatten())
model_2.add(Dense(256, activation='relu'))
model_2.add(Dropout(0.5))
model_2.add(Dense(num_classes, activation='softmax'))
model_2.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])
# Out:
# c:\Users\Subbu\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
hist_2=model_2.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")
model_2.save('mnist_2.h5')
print("Saving the model as mnist_2.h5")
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 30s 63ms/step - accuracy: 0.1289 - loss: 2.2869 - val_accuracy: 0.4504 - val_loss: 2.2219
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 35s 74ms/step - accuracy: 0.2877 - loss: 2.2118 - val_accuracy: 0.6113 - val_loss: 2.1237
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 35s 75ms/step - accuracy: 0.4271 - loss: 2.1150 - val_accuracy: 0.6952 - val_loss: 1.9884
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 36s 76ms/step - accuracy: 0.5249 - loss: 1.9806 - val_accuracy: 0.7377 - val_loss: 1.7985
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 36s 77ms/step - accuracy: 0.5966 - loss: 1.7937 - val_accuracy: 0.7682 - val_loss: 1.5533
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 37s 79ms/step - accuracy: 0.6388 - loss: 1.5703 - val_accuracy: 0.7918 - val_loss: 1.2887
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.6698 - loss: 1.3473 - val_accuracy: 0.8126 - val_loss: 1.0573
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 98ms/step - accuracy: 0.6973 - loss: 1.1579 - val_accuracy: 0.8281 - val_loss: 0.8835
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 99ms/step - accuracy: 0.7200 - loss: 1.0149 - val_accuracy: 0.8378 - val_loss: 0.7605
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 93ms/step - accuracy: 0.7367 - loss: 0.9139 - val_accuracy: 0.8467 - val_loss: 0.6742
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 105ms/step - accuracy: 0.7509 - loss: 0.8417 - val_accuracy: 0.8545 - val_loss: 0.6115
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 63s 134ms/step - accuracy: 0.7648 - loss: 0.7813 - val_accuracy: 0.8616 - val_loss: 0.5647
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 130ms/step - accuracy: 0.7740 - loss: 0.7399 - val_accuracy: 0.8660 - val_loss: 0.5282
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 131ms/step - accuracy: 0.7891 - loss: 0.6925 - val_accuracy: 0.8717 - val_loss: 0.4988
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 67s 143ms/step - accuracy: 0.7998 - loss: 0.6602 - val_accuracy: 0.8763 - val_loss: 0.4751
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 156ms/step - accuracy: 0.8069 - loss: 0.6346 - val_accuracy: 0.8796 - val_loss: 0.4548
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 130ms/step - accuracy: 0.8084 - loss: 0.6194 - val_accuracy: 0.8833 - val_loss: 0.4377
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.8149 - loss: 0.6016 - val_accuracy: 0.8845 - val_loss: 0.4225
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 90ms/step - accuracy: 0.8216 - loss: 0.5777 - val_accuracy: 0.8877 - val_loss: 0.4094
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.8247 - loss: 0.5658 - val_accuracy: 0.8897 - val_loss: 0.3977
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# The model has successfully trained
# Saving the model as mnist_2.h5

# %%
score = model_2.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.39765140414237976
# Test accuracy: 0.8896999955177307

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load the model
model = tf.keras.models.load_model('mnist_2.h5')

# Load MNIST data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_test = np.expand_dims(x_test, -1) / 255.0  # Normalize and add channel dimension

# Test the model with some test images
for i in range(10):
    img = x_test[i]
    label = y_test[i]
    img = np.expand_dims(img, 0)  # Add batch dimension
    prediction = model.predict(img)[0]
    predicted_class = np.argmax(prediction)
    probability = np.max(prediction)
    
    # Plot the image and prediction
    plt.imshow(img[0, :, :, 0], cmap='gray')
    plt.title(f'Label: {label}, Prediction: {predicted_class}, Probability: {probability:.2f}')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Plot both validation loss and training loss
plt.plot(hist_2.history['loss'], label='Training Loss')
plt.plot(hist_2.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Improve the model accuracy version 2 with 30 epochs

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
num_classes=10
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train/255
x_test = x_test/255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
batch_size = 128
num_classes = 10
epochs = 30
model_3 = Sequential()
model_3.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model_3.add(Conv2D(64, (3, 3), activation='relu'))
model_3.add(MaxPooling2D(pool_size=(2, 2)))
model_3.add(Dropout(0.25))
model_3.add(Flatten())
model_3.add(Dense(256, activation='relu'))
model_3.add(Dropout(0.5))
model_3.add(Dense(num_classes, activation='softmax'))
model_3.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])

# %%
hist_3=model_3.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")
model_3.save('mnist_3.h5')
print("Saving the model as mnist_3.h5")
# Out:
# Epoch 1/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 55s 115ms/step - accuracy: 0.1289 - loss: 2.2981 - val_accuracy: 0.3766 - val_loss: 2.2365
# Epoch 2/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 64s 137ms/step - accuracy: 0.2767 - loss: 2.2282 - val_accuracy: 0.5949 - val_loss: 2.1458
# Epoch 3/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 110ms/step - accuracy: 0.4227 - loss: 2.1374 - val_accuracy: 0.6572 - val_loss: 2.0155
# Epoch 4/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 90ms/step - accuracy: 0.5150 - loss: 2.0085 - val_accuracy: 0.7138 - val_loss: 1.8296
# Epoch 5/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 44s 93ms/step - accuracy: 0.5815 - loss: 1.8251 - val_accuracy: 0.7586 - val_loss: 1.5833
# Epoch 6/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 91ms/step - accuracy: 0.6277 - loss: 1.5978 - val_accuracy: 0.7922 - val_loss: 1.3103
# Epoch 7/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 92ms/step - accuracy: 0.6679 - loss: 1.3595 - val_accuracy: 0.8113 - val_loss: 1.0669
# Epoch 8/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.6926 - loss: 1.1676 - val_accuracy: 0.8266 - val_loss: 0.8842
# Epoch 9/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 44s 95ms/step - accuracy: 0.7143 - loss: 1.0265 - val_accuracy: 0.8370 - val_loss: 0.7567
# Epoch 10/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 44s 94ms/step - accuracy: 0.7356 - loss: 0.9177 - val_accuracy: 0.8460 - val_loss: 0.6682
# Epoch 11/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 44s 95ms/step - accuracy: 0.7547 - loss: 0.8355 - val_accuracy: 0.8554 - val_loss: 0.6045
# Epoch 12/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 44s 93ms/step - accuracy: 0.7651 - loss: 0.7812 - val_accuracy: 0.8611 - val_loss: 0.5571
# Epoch 13/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.7806 - loss: 0.7330 - val_accuracy: 0.8685 - val_loss: 0.5201
# Epoch 14/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.7922 - loss: 0.6860 - val_accuracy: 0.8724 - val_loss: 0.4909
# Epoch 15/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 82ms/step - accuracy: 0.7980 - loss: 0.6604 - val_accuracy: 0.8776 - val_loss: 0.4668
# Epoch 16/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 38s 82ms/step - accuracy: 0.8068 - loss: 0.6314 - val_accuracy: 0.8812 - val_loss: 0.4470
# Epoch 17/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 38s 81ms/step - accuracy: 0.8097 - loss: 0.6134 - val_accuracy: 0.8835 - val_loss: 0.4303
# Epoch 18/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 38s 82ms/step - accuracy: 0.8171 - loss: 0.5948 - val_accuracy: 0.8865 - val_loss: 0.4154
# Epoch 19/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 83ms/step - accuracy: 0.8271 - loss: 0.5649 - val_accuracy: 0.8910 - val_loss: 0.4023
# Epoch 20/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 38s 81ms/step - accuracy: 0.8294 - loss: 0.5610 - val_accuracy: 0.8931 - val_loss: 0.3911
# Epoch 21/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 83ms/step - accuracy: 0.8327 - loss: 0.5437 - val_accuracy: 0.8950 - val_loss: 0.3812
# Epoch 22/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 86ms/step - accuracy: 0.8362 - loss: 0.5308 - val_accuracy: 0.8991 - val_loss: 0.3718
# Epoch 23/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 92ms/step - accuracy: 0.8380 - loss: 0.5291 - val_accuracy: 0.9012 - val_loss: 0.3638
# Epoch 24/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 90ms/step - accuracy: 0.8431 - loss: 0.5125 - val_accuracy: 0.9016 - val_loss: 0.3560
# Epoch 25/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 83ms/step - accuracy: 0.8503 - loss: 0.4963 - val_accuracy: 0.9032 - val_loss: 0.3491
# Epoch 26/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 53s 113ms/step - accuracy: 0.8507 - loss: 0.4894 - val_accuracy: 0.9052 - val_loss: 0.3427
# Epoch 27/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 59s 127ms/step - accuracy: 0.8515 - loss: 0.4806 - val_accuracy: 0.9062 - val_loss: 0.3371
# Epoch 28/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 90ms/step - accuracy: 0.8566 - loss: 0.4735 - val_accuracy: 0.9088 - val_loss: 0.3318
# Epoch 29/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 89ms/step - accuracy: 0.8574 - loss: 0.4688 - val_accuracy: 0.9098 - val_loss: 0.3265
# Epoch 30/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 89ms/step - accuracy: 0.8569 - loss: 0.4634 - val_accuracy: 0.9102 - val_loss: 0.3215
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# The model has successfully trained
# Saving the model as mnist_3.h5

# %%
score = model_3.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.3220890760421753
# Test accuracy: 0.9104999899864197

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load the model
model = tf.keras.models.load_model('mnist_3.h5')

# Load MNIST data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_test = np.expand_dims(x_test, -1) / 255.0  # Normalize and add channel dimension

# Test the model with some test images
for i in range(10):
    img = x_test[i]
    label = y_test[i]
    img = np.expand_dims(img, 0)  # Add batch dimension
    prediction = model.predict(img)[0]
    predicted_class = np.argmax(prediction)
    probability = np.max(prediction)
    
    # Plot the image and prediction
    plt.imshow(img[0, :, :, 0], cmap='gray')
    plt.title(f'Label: {label}, Prediction: {predicted_class}, Probability: {probability:.2f}')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
# Plot both validation loss and training loss
plt.plot(hist_3.history['loss'], label='Training Loss')
plt.plot(hist_3.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Improve the model accuracy version 3 with 50 epochs

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
num_classes=10
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train/255
x_test = x_test/255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
batch_size = 128
num_classes = 10
epochs = 50
model_4 = Sequential()
model_4.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model_4.add(Conv2D(64, (3, 3), activation='relu'))
model_4.add(MaxPooling2D(pool_size=(2, 2)))
model_4.add(Dropout(0.25))
model_4.add(Flatten())
model_4.add(Dense(256, activation='relu'))
model_4.add(Dropout(0.5))
model_4.add(Dense(num_classes, activation='softmax'))
model_4.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])

# %%
hist_4=model_4.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")
model_4.save('mnist_4.h5')
print("Saving the model as mnist_4.h5")
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 36s 71ms/step - accuracy: 0.1370 - loss: 2.2921 - val_accuracy: 0.4067 - val_loss: 2.2393
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.2772 - loss: 2.2308 - val_accuracy: 0.5638 - val_loss: 2.1585
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.4018 - loss: 2.1518 - val_accuracy: 0.6588 - val_loss: 2.0460
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.5030 - loss: 2.0411 - val_accuracy: 0.7139 - val_loss: 1.8861
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.5770 - loss: 1.8784 - val_accuracy: 0.7484 - val_loss: 1.6658
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.6273 - loss: 1.6673 - val_accuracy: 0.7789 - val_loss: 1.4041
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.6611 - loss: 1.4399 - val_accuracy: 0.7992 - val_loss: 1.1538
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.6909 - loss: 1.2286 - val_accuracy: 0.8160 - val_loss: 0.9517
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 37s 79ms/step - accuracy: 0.7160 - loss: 1.0596 - val_accuracy: 0.8324 - val_loss: 0.8052
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 38s 82ms/step - accuracy: 0.7349 - loss: 0.9476 - val_accuracy: 0.8432 - val_loss: 0.7043
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 30s 65ms/step - accuracy: 0.7547 - loss: 0.8550 - val_accuracy: 0.8528 - val_loss: 0.6321
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 30s 63ms/step - accuracy: 0.7655 - loss: 0.7895 - val_accuracy: 0.8597 - val_loss: 0.5783
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 31s 67ms/step - accuracy: 0.7732 - loss: 0.7525 - val_accuracy: 0.8652 - val_loss: 0.5382
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.7894 - loss: 0.7000 - val_accuracy: 0.8715 - val_loss: 0.5058
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.8027 - loss: 0.6609 - val_accuracy: 0.8761 - val_loss: 0.4795
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.8111 - loss: 0.6322 - val_accuracy: 0.8805 - val_loss: 0.4578
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.8171 - loss: 0.6078 - val_accuracy: 0.8847 - val_loss: 0.4399
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.8191 - loss: 0.5939 - val_accuracy: 0.8875 - val_loss: 0.4242
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.8240 - loss: 0.5749 - val_accuracy: 0.8904 - val_loss: 0.4107
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8330 - loss: 0.5560 - val_accuracy: 0.8929 - val_loss: 0.3984
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.8332 - loss: 0.5458 - val_accuracy: 0.8952 - val_loss: 0.3878
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.8378 - loss: 0.5308 - val_accuracy: 0.8977 - val_loss: 0.3781
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 71ms/step - accuracy: 0.8417 - loss: 0.5191 - val_accuracy: 0.8989 - val_loss: 0.3697
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.8424 - loss: 0.5134 - val_accuracy: 0.9011 - val_loss: 0.3621
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 71ms/step - accuracy: 0.8468 - loss: 0.5003 - val_accuracy: 0.9028 - val_loss: 0.3546
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8525 - loss: 0.4902 - val_accuracy: 0.9041 - val_loss: 0.3481
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8529 - loss: 0.4836 - val_accuracy: 0.9049 - val_loss: 0.3421
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8556 - loss: 0.4740 - val_accuracy: 0.9067 - val_loss: 0.3364
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8558 - loss: 0.4704 - val_accuracy: 0.9069 - val_loss: 0.3314
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8609 - loss: 0.4562 - val_accuracy: 0.9083 - val_loss: 0.3265
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 35s 74ms/step - accuracy: 0.8632 - loss: 0.4445 - val_accuracy: 0.9087 - val_loss: 0.3216
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8648 - loss: 0.4480 - val_accuracy: 0.9097 - val_loss: 0.3171
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8650 - loss: 0.4404 - val_accuracy: 0.9121 - val_loss: 0.3126
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8690 - loss: 0.4338 - val_accuracy: 0.9129 - val_loss: 0.3085
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8717 - loss: 0.4252 - val_accuracy: 0.9146 - val_loss: 0.3044
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8721 - loss: 0.4240 - val_accuracy: 0.9153 - val_loss: 0.3008
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8742 - loss: 0.4180 - val_accuracy: 0.9159 - val_loss: 0.2968
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8769 - loss: 0.4125 - val_accuracy: 0.9162 - val_loss: 0.2936
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8763 - loss: 0.4077 - val_accuracy: 0.9166 - val_loss: 0.2902
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8774 - loss: 0.4048 - val_accuracy: 0.9175 - val_loss: 0.2871
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8797 - loss: 0.4007 - val_accuracy: 0.9182 - val_loss: 0.2839
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8815 - loss: 0.3962 - val_accuracy: 0.9188 - val_loss: 0.2810
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8842 - loss: 0.3878 - val_accuracy: 0.9200 - val_loss: 0.2776
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8831 - loss: 0.3867 - val_accuracy: 0.9205 - val_loss: 0.2750
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8816 - loss: 0.3855 - val_accuracy: 0.9210 - val_loss: 0.2727
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8858 - loss: 0.3762 - val_accuracy: 0.9219 - val_loss: 0.2697
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8858 - loss: 0.3770 - val_accuracy: 0.9225 - val_loss: 0.2668
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.8877 - loss: 0.3719 - val_accuracy: 0.9230 - val_loss: 0.2644
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8884 - loss: 0.3723 - val_accuracy: 0.9237 - val_loss: 0.2620
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.8891 - loss: 0.3672 - val_accuracy: 0.9243 - val_loss: 0.2597
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# The model has successfully trained
# Saving the model as mnist_4.h5

# %%
score = model_4.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.25969815254211426
# Test accuracy: 0.9243000149726868

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load the model
model = tf.keras.models.load_model('mnist_4.h5')

# Load MNIST data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_test = np.expand_dims(x_test, -1) / 255.0  # Normalize and add channel dimension

# Test the model with some test images
for i in range(10):
    img = x_test[i]
    label = y_test[i]
    img = np.expand_dims(img, 0)  # Add batch dimension
    prediction = model.predict(img)[0]
    predicted_class = np.argmax(prediction)
    probability = np.max(prediction)
    
    # Plot the image and prediction
    plt.imshow(img[0, :, :, 0], cmap='gray')
    plt.title(f'Label: {label}, Prediction: {predicted_class}, Probability: {probability:.2f}')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
# Plot both validation loss and training loss
plt.plot(hist_4.history['loss'], label='Training Loss')
plt.plot(hist_4.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
